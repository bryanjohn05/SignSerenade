# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11m-cls.yaml")  # build a new model from YAML

# Train the model
results = model.train(data="/Users/maxonfernandes/Desktop/SignSerenade/Data", epochs=15, imgsz=64)
# Out:
# YOLO11m-cls summary: 187 layers, 10,455,696 parameters, 10,455,696 gradients, 39.7 GFLOPs
# Ultralytics 8.3.49 🚀 Python-3.12.0 torch-2.5.1 CPU (Apple M1)
# ...
